# %% [markdown]
# ## Data Analytics in Python  -> ML -> AI

# %%
# Descriptive Analysis
# Diagnostic Analysis
# Predictive Analysis  - Machine Learning / Deep Learning
# Prescriptive Analysis  - AI

# %%
# !python -m pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ## DATA TYPES
#
# #  1. Series: 1-D Data, single column data
# #  2. DataFrame: 2-D Data, multi- column/Tabular data
# #  3. Panel: 3-D Data, multi-table data

# %%
s1 = pd.Series([4,6,8,934,3])
s1
# Out:
# 0      4
# 1      6
# 2      8
# 3    934
# 4      3
# dtype: int64

# %%
s2 = pd.Series(['hi','nice','hi','nice','go'])
s2
# Out:
# 0      hi
# 1    nice
# 2      hi
# 3    nice
# 4      go
# dtype: object

# %%
s1.sum()
# Out:
# 955

# %%
s1.mean()
# Out:
# 191.0

# %%
s2.value_counts()
# Out:
# hi      2
# nice    2
# go      1
# Name: count, dtype: int64

# %%
s1 < 10
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
s1[0]
# Out:
# 4

# %%
s1[s1<10]
#indexing
# Out:
# 0    4
# 1    6
# 2    8
# 4    3
# dtype: int64

# %%
s2.str.upper()
# Out:
# 0      HI
# 1    NICE
# 2      HI
# 3    NICE
# 4      GO
# dtype: object

# %%
 s3 = pd.Series({'a':45,'b':78,'c':90,'d':90,'e':78})
s3
# Out:
# a    45
# b    78
# c    90
# d    90
# e    78
# dtype: int64

# %%
s3['b']
# Out:
# 78

# %%
s3[1]
# Out:
# 78

# %%
s4 = pd.Series([7,3,6,8,3], index = ['a','x','p','n','k'])
s4
# Out:
# a    7
# x    3
# p    6
# n    8
# k    3
# dtype: int64

# %%
s4.unique()
# Out:
# array([7, 3, 6, 8], dtype=int64)

# %%
s4.nunique()
# Out:
# 4

# %%
s4.values
# Out:
# array([7, 3, 6, 8, 3], dtype=int64)

# %%
s4.max()
# Out:
# 8

# %%
s4.idxmax()
# Out:
# 'n'

# %%
s4.T
# Out:
# a    7
# x    3
# p    6
# n    8
# k    3
# dtype: int64

# %%
df = pd.DataFrame([[5,6,7],[5,3,8],[5,8,9],[2,3,4]])
df
# Out:
#    0  1  2
# 0  5  6  7
# 1  5  3  8
# 2  5  8  9
# 3  2  3  4

# %%
df[0]
# Out:
# 0    5
# 1    5
# 2    5
# 3    2
# Name: 0, dtype: int64

# %%
df[0][3]
# Out:
# 2

# %%
df.loc[1]
# Out:
# 0    5
# 1    3
# 2    8
# Name: 1, dtype: int64

# %%
df1 = pd.DataFrame({'a':[4,5,6,7,8,9,3,4], 'b':['hi','hi','bye','go','hi','hi','bye','go']})
df1
# Out:
#    a    b
# 0  4   hi
# 1  5   hi
# 2  6  bye
# 3  7   go
# 4  8   hi
# 5  9   hi
# 6  3  bye
# 7  4   go

# %%
df1['a']
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# 5    9
# 6    3
# 7    4
# Name: a, dtype: int64

# %%
df1.shape
# Out:
# (8, 2)

# %%
df1.count()
# Out:
# a    8
# b    8
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       8 non-null      int64
#  1   b       8 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df1.size
# Out:
# 16

# %%
df1.head(4)
# Out:
#    a    b
# 0  4   hi
# 1  5   hi
# 2  6  bye
# 3  7   go

# %%
df1.tail(2)
# Out:
#    a    b
# 6  3  bye
# 7  4   go

# %%
df1['new'] = pd.Series([6,2,54,7,3,67,3,4])
df1
# Out:
#    a    b  new
# 0  4   hi    6
# 1  5   hi    2
# 2  6  bye   54
# 3  7   go    7
# 4  8   hi    3
# 5  9   hi   67
# 6  3  bye    3
# 7  4   go    4

# %%
df1[['b','new']]
# Out:
#      b  new
# 0   hi    6
# 1   hi    2
# 2  bye   54
# 3   go    7
# 4   hi    3
# 5   hi   67
# 6  bye    3
# 7   go    4

# %%
df1[['b','new']][df1['new']%2==1]
# Out:
#      b  new
# 3   go    7
# 4   hi    3
# 5   hi   67
# 6  bye    3

# %%
df1.describe(include='all')
# Out:
#               a    b        new
# count   8.00000    8   8.000000
# unique      NaN    3        NaN
# top         NaN   hi        NaN
# freq        NaN    4        NaN
# mean    5.75000  NaN  18.250000
# std     2.12132  NaN  26.358788
# min     3.00000  NaN   2.000000
# 25%     4.00000  NaN   3.000000
# 50%     5.50000  NaN   5.000000
# 75%     7.25000  NaN  18.750000
# max     9.00000  NaN  67.000000

# %%
df1.describe()
# Out:
#              a        new
# count  8.00000   8.000000
# mean   5.75000  18.250000
# std    2.12132  26.358788
# min    3.00000   2.000000
# 25%    4.00000   3.000000
# 50%    5.50000   5.000000
# 75%    7.25000  18.750000
# max    9.00000  67.000000

# %%
# del df1['a']
df1.drop(['a'], axis=1, inplace=True)

# %%
df1.sample(3)
# Out:
#     b  new
# 7  go    4
# 4  hi    3
# 1  hi    2

# %%
## Series/DataFrame
    # - Create
    # - Access
    # - New Item Insert (DF)
    # - Deletion (df.drop())

    # Description
    ### info()
    ### unique()
    ### nunique()
    ### shape
    ### size
    ### count()
    ### describe()
    ### value_counts
    ### head()
    ### tail()
    ### sample()
    ### columns()
    ### index()

    # Stats
    ### sum()
    ### min()
    ### max()
    ### mean()
    ### idxmax()
    ### idxmin()

# %% [markdown]
# # File OPerations
#
# # read
#     # pd.read_csv
#     # pd.read_json
#     # pd.read_excel
#     # .......
# # write
#     # df.to_csv('file.csv)
#     # df........

# %%
suicide = pd.read_csv(r'suicide_data/State-wise Distribution_2021.csv')

# %%
suicide.sample(5)
# Out:
#    Category        State/UT  By Consuming Sleeping Pills - Male
# 26    State     Uttarakhand                                   0  \
# 37       UT     Total (UTs)                                  54
# 32       UT           Delhi                                  52
# 12    State  Madhya Pradesh                                  52
# 35       UT     Lakshadweep                                   0
#
#     By Consuming Sleeping Pills - Female
# 26                                     0  \
# 37                                    30
# 32                                    29
# 12                                    15
# 35                                     0
#
#     By Consuming Sleeping Pills - Transgender
# 26                                          0  \
# 37                                          0
# 32                                          0
# 12                                          0
# 35                                          0
#
# ...

# %%
68/4
# Out:
# 17.0

# %%
suicide.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 70 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Category                                                       39 non-null     object
#  1   State/UT                                                       39 non-null     object
#  2   By Consuming Sleeping Pills - Male                             39 non-null     int64
#  3   By Consuming Sleeping Pills - Female                           39 non-null     int64
#  4   By Consuming Sleeping Pills - Transgender                      39 non-null     int64
#  5   By Consuming Sleeping Pills - Total                            39 non-null     int64
#  6   By Drowning - Male                                             39 non-null     int64
# ...

# %%
suicide.columns
# Out:
# Index(['Category', 'State/UT', 'By Consuming Sleeping Pills - Male',
#        'By Consuming Sleeping Pills - Female',
#        'By Consuming Sleeping Pills - Transgender',
#        'By Consuming Sleeping Pills - Total', 'By Drowning - Male',
#        'By Drowning - Female', 'By Drowning - Transgender',
#        'By Drowning - Total', 'By Fire/Self Immolation - Male',
#        'By Fire/Self Immolation - Female',
#        'By Fire/Self Immolation - Transgender',
#        'By Fire/Self Immolation - Total', 'By Firearms - Male',
#        'By Firearms - Female', 'By Firearms - Transgender',
#        'By Firearms - Total', 'By Hanging - Male', 'By Hanging - Female',
#        'By Hanging - Transgender', 'By Hanging - Total',
#        'By Poison (Total) - Male', 'By Poison (Total) - Female',
#        'By Poison (Total) - Transgender', 'By Poison (Total) - Total',
#        'By Poison (By Consuming Insecticides) - Male',
#        'By Poison (By Consuming Insecticides) - Female',
# ...

# %%
for col in suicide.columns:
      print(col)
# Out:
# Category
# State/UT
# By Consuming Sleeping Pills - Male
# By Consuming Sleeping Pills - Female
# By Consuming Sleeping Pills - Transgender
# By Consuming Sleeping Pills - Total
# By Drowning - Male
# By Drowning - Female
# By Drowning - Transgender
# By Drowning - Total
# By Fire/Self Immolation - Male
# By Fire/Self Immolation - Female
# By Fire/Self Immolation - Transgender
# By Fire/Self Immolation - Total
# By Firearms - Male
# By Firearms - Female
# By Firearms - Transgender
# By Firearms - Total
# By Hanging - Male
# By Hanging - Female
# By Hanging - Transgender
# By Hanging - Total
# By Poison (Total) - Male
# By Poison (Total) - Female
# By Poison (Total) - Transgender
# By Poison (Total) - Total
# By Poison (By Consuming Insecticides) - Male
# By Poison (By Consuming Insecticides) - Female
# By Poison (By Consuming Insecticides) - Transgender
# By Poison (By Consuming Insecticides) - Total
# By Poison (By Consuming other Poison) - Male
# ...

# %%
my_cols = ['State/UT'] + list(suicide.columns[5::4])

# %%
df = suicide[my_cols]
df.head
# Out:
# <bound method NDFrame.head of                                     State/UT
# 0                             Andhra Pradesh  \
# 1                          Arunachal Pradesh
# 2                                      Assam
# 3                                      Bihar
# 4                               Chhattisgarh
# 5                                        Goa
# 6                                    Gujarat
# 7                                    Haryana
# 8                           Himachal Pradesh
# 9                                  Jharkhand
# 10                                 Karnataka
# 11                                    Kerala
# 12                            Madhya Pradesh
# 13                               Maharashtra
# 14                                   Manipur
# 15                                 Meghalaya
# 16                                   Mizoram
# 17                                  Nagaland
# 18                                    Odisha
# ...

# %%
df.to_csv('suicides_data.csv',index=False)
df.to_csv('suicides_data.csv')

# %%
#read_file = pd.read_csv('suicides_data.csv')
read_file = pd.read_csv('suicides_data.csv', index_col=0)
read_file.head()
# Out:
#             State/UT  By Consuming Sleeping Pills - Total
# 0     Andhra Pradesh                                   44  \
# 1  Arunachal Pradesh                                    0
# 2              Assam                                    8
# 3              Bihar                                   55
# 4       Chhattisgarh                                    0
#
#    By Drowning - Total  By Fire/Self Immolation - Total  By Firearms - Total
# 0                  328                              145                    4  \
# 1                    9                                0                    2
# 2                  262                               18                    1
# 3                   36                               14                   21
# 4                  145                              368                    6
#
#    By Hanging - Total  By Poison (Total) - Total
# 0                2962                       3818  \
# 1                 107                          1
# ...

# %% [markdown]
# ### Pandas Features
#
#     # 1. String Functions -
#     "# 2. Merging/Joining - merge, join, concat
#     "# 3. Missing Data
#     "# 4. Statisticial
#     "# 5. Data Iteration
#     "# 6. Data Grouping
#     "# 7. Aggregation
#     "# 8. Sorting
#     "# 9. Function Application
#     "### Logical Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv('suicides_data.csv')
df.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0                                  State/UT
# 0            0                            Andhra Pradesh  \
# 1            1                         Arunachal Pradesh
# 2            2                                     Assam
# 3            3                                     Bihar
# 4            4                              Chhattisgarh
# 5            5                                       Goa
# 6            6                                   Gujarat
# 7            7                                   Haryana
# 8            8                          Himachal Pradesh
# 9            9                                 Jharkhand
# 10          10                                 Karnataka
# 11          11                                    Kerala
# 12          12                            Madhya Pradesh
# 13          13                               Maharashtra
# 14          14                                   Manipur
# ...

# %% [markdown]
# # String Function
# ## works on series
# ## series.str.function()

# %%
df['State/UT'].str.count('a')
df['State/UT'].str.contains('a')
df['State/UT'].str.find('a')
df['State/UT'].str.get_dummies()
df['State/UT'].str.get(0)
df['State/UT'].str.join('+')
df['State/UT'].str.lower().str.count('a')
df['State/UT'].str.repeat([3,3,2,4,2,4,2,2,3,1,3,3,2,4,2,4,2,2,3,13,3,2,4,2,4,2,2,3,1,3,3,2,4,2,4,2,2,3,1])
df['State/UT'].str.replace('A','K', case=False)
df['State/UT'].str.upper()
df['State/UT'].str.split().str.get(0)
df['State/UT'].str.len()
# Out:
# 0     14
# 1     17
# 2      5
# 3      5
# 4     12
# 5      3
# 6      7
# 7      7
# 8     16
# 9      9
# 10     9
# 11     6
# 12    14
# 13    11
# 14     7
# 15     9
# 16     7
# 17     8
# 18     6
# 19     6
# 20     9
# 21     6
# 22    10
# 23     9
# 24     7
# 25    13
# 26    11
# 27    11
# 28    14
# 29    27
# 30    10
# 31    40
# 32     5
# 33    17
# 34     6
# 35    11
# 36    10
# 37    11
# 38    17
# Name: State/UT, dtype: int64

# %%
df1 = pd.DataFrame({'name':['John','Victor','Michael','Viriginia','Mike'], 'id':[3,4,1,2,5]})
df1
# Out:
#         name  id
# 0       John   3
# 1     Victor   4
# 2    Michael   1
# 3  Viriginia   2
# 4       Mike   5

# %%
df2 = pd.DataFrame({'domain':['IT','Sales','Sales','HomeMaker','Manager'], 'id':[1,2,3,9,6]})
df2
# Out:
#       domain  id
# 0         IT   1
# 1      Sales   2
# 2      Sales   3
# 3  HomeMaker   9
# 4    Manager   6

# %%
df3 = pd.DataFrame({'city':['NY','London','Dublin','Torronto','Texas'], 'id':[3,2,1,9,5]})
df3
# Out:
#        city  id
# 0        NY   3
# 1    London   2
# 2    Dublin   1
# 3  Torronto   9
# 4     Texas   5

# %%
pd.merge(df1, df2, on='id')
# Out:
#         name  id domain
# 0       John   3  Sales
# 1    Michael   1     IT
# 2  Viriginia   2  Sales

# %%
pd.merge(df1, df2, on='id', how='outer')
# Out:
#         name  id     domain
# 0       John   3      Sales
# 1     Victor   4        NaN
# 2    Michael   1         IT
# 3  Viriginia   2      Sales
# 4       Mike   5        NaN
# 5        NaN   9  HomeMaker
# 6        NaN   6    Manager

# %%
pd.merge(df1, df2, on='id', how='left')
# Out:
#         name  id domain
# 0       John   3  Sales
# 1     Victor   4    NaN
# 2    Michael   1     IT
# 3  Viriginia   2  Sales
# 4       Mike   5    NaN

# %%
pd.concat([df1,df3],axis=1)
#axis = 1 means coloumn wise
#axis = 0 means row wise
# Out:
#         name  id      city  id
# 0       John   3        NY   3
# 1     Victor   4    London   2
# 2    Michael   1    Dublin   1
# 3  Viriginia   2  Torronto   9
# 4       Mike   5     Texas   5

# %%
df1, df3
# Out:
# (        name  id
#  0       John   3
#  1     Victor   4
#  2    Michael   1
#  3  Viriginia   2
#  4       Mike   5,
#         city  id
#  0        NY   3
#  1    London   2
#  2    Dublin   1
#  3  Torronto   9
#  4     Texas   5)

# %%
df1.join(df3, rsuffix='_right',how='inner')   #,on='id')
# Out:
#         name  id      city  id_right
# 0       John   3        NY         3
# 1     Victor   4    London         2
# 2    Michael   1    Dublin         1
# 3  Viriginia   2  Torronto         9
# 4       Mike   5     Texas         5

# %%
df4 = df1.join(df3, rsuffix='_right',how='inner')   #,on='id')
df4
# Out:
#         name  id      city  id_right
# 0       John   3        NY         3
# 1     Victor   4    London         2
# 2    Michael   1    Dublin         1
# 3  Viriginia   2  Torronto         9
# 4       Mike   5     Texas         5

# %% [markdown]
# ## Logical Indexing

# %%
df4['city'].str.len() > 5
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: city, dtype: bool

# %%
df4[df4['city'].str.len() > 5]
# Out:
#         name  id      city  id_right
# 1     Victor   4    London         2
# 2    Michael   1    Dublin         1
# 3  Viriginia   2  Torronto         9

# %%
(df4['city'].str.len() > 5) & (df4['name'].str.len() < 7)& (df4['name'].str.len() > 3)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df4[(df4['city'].str.len() > 5) & (df4['name'].str.len() < 7)& (df4['name'].str.len() > 3)]
# Out:
#      name  id    city  id_right
# 1  Victor   4  London         2

# %% [markdown]
# # Missing Data

# %%
df12 = pd.merge(df1, df2, on='id', how='outer')
df123 = pd.merge(df12, df3, on='id', how='outer')
df123
# Out:
#         name  id     domain      city
# 0       John   3      Sales        NY
# 1     Victor   4        NaN       NaN
# 2    Michael   1         IT    Dublin
# 3  Viriginia   2      Sales    London
# 4       Mike   5        NaN     Texas
# 5        NaN   9  HomeMaker  Torronto
# 6        NaN   6    Manager       NaN

# %%
df123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   id      7 non-null      int64
#  2   domain  5 non-null      object
#  3   city    5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 352.0+ bytes

# %%
pd.isnull(df123)
# Out:
#     name     id  domain   city
# 0  False  False   False  False
# 1  False  False    True   True
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False  False    True  False
# 5   True  False   False  False
# 6   True  False   False   True

# %%
pd.isnull(df123).sum()
#missing
# Out:
# name      2
# id        0
# domain    2
# city      2
# dtype: int64

# %%
100 * pd.isnull(df123).sum()/len(df123)
# Out:
# name      28.571429
# id         0.000000
# domain    28.571429
# city      28.571429
# dtype: float64

# %%
df123.isna()
# Out:
#     name     id  domain   city
# 0  False  False   False  False
# 1  False  False    True   True
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False  False    True  False
# 5   True  False   False  False
# 6   True  False   False   True

# %%
df123.fillna('NoValue')
# Out:
#         name  id     domain      city
# 0       John   3      Sales        NY
# 1     Victor   4    NoValue   NoValue
# 2    Michael   1         IT    Dublin
# 3  Viriginia   2      Sales    London
# 4       Mike   5    NoValue     Texas
# 5    NoValue   9  HomeMaker  Torronto
# 6    NoValue   6    Manager   NoValue

# %%
df123.fillna('NoValue').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   id      7 non-null      int64
#  2   domain  7 non-null      object
#  3   city    7 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 352.0+ bytes

# %%
import numpy as np

# %%
d = pd.DataFrame({'a':[4,6,2,5,25,6], 'b':[5,3,np.nan,np.nan,10,23]})
d
# Out:
#     a     b
# 0   4   5.0
# 1   6   3.0
# 2   2   NaN
# 3   5   NaN
# 4  25  10.0
# 5   6  23.0

# %%
dd = d.fillna(d['b'].mean())

# %% [markdown]
# # Missing Data Problem?
#     #### Methods to cure
#     ####### 1. Drop the columns (>20% missing)
#     ####### 2. Drop the rows    (>20% missing)
#     ####### 3. Fill with dummy data

# %% [markdown]
# ## Statistical Functions

# %%
dd.mean()
dd.sum()
dd.count()
dd.std()
dd.var()
dd.corr()
dd.median()
dd.quantile(0.25)
dd.quantile(0.75)
dd.min()
dd.max()
dd.round(1)
dd.prod()
# Out:
# a     36000.000
# b    362465.625
# dtype: float64

# %% [markdown]
# ## Data Iteration

# %%
 # oridinary way

for i in df123:
     print(i)
# Out:
# name
# id
# domain
# city

# %%
df123
# Out:
#         name  id     domain      city
# 0       John   3      Sales        NY
# 1     Victor   4        NaN       NaN
# 2    Michael   1         IT    Dublin
# 3  Viriginia   2      Sales    London
# 4       Mike   5        NaN     Texas
# 5        NaN   9  HomeMaker  Torronto
# 6        NaN   6    Manager       NaN

# %%
for ind, val in df123.iterrows():  # generator
      print(ind)
      print(val)
      print('')
# Out:
# 0
# name       John
# id            3
# domain    Sales
# city         NY
# Name: 0, dtype: object
#
# 1
# name      Victor
# id             4
# domain       NaN
# city         NaN
# Name: 1, dtype: object
#
# 2
# name      Michael
# id              1
# domain         IT
# city       Dublin
# Name: 2, dtype: object
#
# 3
# name      Viriginia
# id                2
# domain        Sales
# city         London
# Name: 3, dtype: object
#
# 4
# name       Mike
# id            5
# domain      NaN
# city      Texas
# Name: 4, dtype: object
#
# 5
# name            NaN
# id                9
# domain    HomeMaker
# city       Torronto
# Name: 5, dtype: object
#
# 6
# name          NaN
# id              6
# domain    Manager
# city          NaN
# Name: 6, dtype: object

# %%
for i in df123.itertuples():
 print(i)
# Out:
# Pandas(Index=0, name='John', id=3, domain='Sales', city='NY')
# Pandas(Index=1, name='Victor', id=4, domain=nan, city=nan)
# Pandas(Index=2, name='Michael', id=1, domain='IT', city='Dublin')
# Pandas(Index=3, name='Viriginia', id=2, domain='Sales', city='London')
# Pandas(Index=4, name='Mike', id=5, domain=nan, city='Texas')
# Pandas(Index=5, name=nan, id=9, domain='HomeMaker', city='Torronto')
# Pandas(Index=6, name=nan, id=6, domain='Manager', city=nan)

# %%
i.domain
# Out:
# 'Manager'

# %%
i[3]
# Out:
# 'Manager'

# %% [markdown]
# # Data Grouping

# %%
# !python -m pip install seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('tips.csv', index_col=0)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 15.2+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df['total_bill'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64>

# %%
df['tip'].mean()
# Out:
# 2.99827868852459

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df[df['sex'] == 'Male']['total_bill'].mean()
# Out:
# 20.744076433121016

# %%
df[df['sex'] == 'Female']['total_bill'].mean()
# Out:
# 18.056896551724133

# %%
df[df['sex'] == 'Male']['tip'].mean()
,
df[df['sex'] == 'Female']['tip'].mean()
# Out:
# 2.8334482758620685

# %%
df[df['day'] == 'Sun']['total_bill'].mean(),
df[df['day'] == 'Sun']['tip'].mean()
# Out:
# 3.2551315789473687

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df.groupby('day')[['total_bill','tip']].mean()
# Out:
#       total_bill       tip
# day
# Fri    17.151579  2.734737
# Sat    20.441379  2.993103
# Sun    21.410000  3.255132
# Thur   17.682742  2.771452

# %%
df.groupby('sex') [['total_bill','tip']].mean()
# Out:
#         total_bill       tip
# sex
# Female   18.056897  2.833448
# Male     20.744076  3.089618

# %%
df.groupby(['sex','day'])[['total_bill','tip']].mean()
# Out:
#              total_bill       tip
# sex    day
# Female Fri    14.145556  2.781111
#        Sat    19.680357  2.801786
#        Sun    19.872222  3.367222
#        Thur   16.715312  2.575625
# Male   Fri    19.857000  2.693000
#        Sat    20.802542  3.083898
#        Sun    21.887241  3.220345
#        Thur   18.714667  2.980333

# %% [markdown]
# # Aggregation

# %%
import numpy as np

# %%
df.groupby(['sex','day'])[['total_bill','tip']].agg([sum, np.mean, np.std])
# Out:
#             total_bill                           tip
#                    sum       mean        std     sum      mean       std
# sex    day
# Female Fri      127.31  14.145556   4.788547   25.03  2.781111  0.938862
#        Sat      551.05  19.680357   8.806470   78.45  2.801786  1.234480
#        Sun      357.70  19.872222   7.837513   60.61  3.367222  1.136775
#        Thur     534.89  16.715312   7.759764   82.42  2.575625  1.109286
# Male   Fri      198.57  19.857000  10.015847   26.93  2.693000  1.136428
#        Sat     1227.35  20.802542   9.836306  181.95  3.083898  1.791360
#        Sun     1269.46  21.887241   9.129142  186.78  3.220345  1.271172
#        Thur     561.44  18.714667   8.019728   89.41  2.980333  1.353734

# %% [markdown]
# # Data Sorting

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.sort_values(by='total_bill')
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df.sort_index(axis=1)  # axis = 1 -> Column, 0 -> Index
# Out:
#       day     sex  size smoker    time   tip  total_bill
# 0     Sun  Female     2     No  Dinner  1.01       16.99
# 1     Sun    Male     3     No  Dinner  1.66       10.34
# 2     Sun    Male     3     No  Dinner  3.50       21.01
# 3     Sun    Male     2     No  Dinner  3.31       23.68
# 4     Sun  Female     4     No  Dinner  3.61       24.59
# ..    ...     ...   ...    ...     ...   ...         ...
# 239   Sat    Male     3     No  Dinner  5.92       29.03
# 240   Sat  Female     2    Yes  Dinner  2.00       27.18
# 241   Sat    Male     2    Yes  Dinner  2.00       22.67
# 242   Sat    Male     2     No  Dinner  1.75       17.82
# 243  Thur  Female     2     No  Dinner  3.00       18.78
#
# [244 rows x 7 columns]

# %%
df.sort_values(by='total_bill', ascending = False)
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %% [markdown]
# # Function Application

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# total_price = (candidate_total_bill + candidate_tip)
# mean(total_price) Gender - wise
# every entry should have their respective Mean Value

# %%
df['total_price'] = df['total_bill'] + df['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_price
# 0       16.99  1.01  Female     No  Sun  Dinner     2        18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3        12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3        24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2        26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4        28.20

# %%
df.groupby('sex')['total_price'].mean()
# Out:
# sex
# Female    20.890345
# Male      23.833694
# Name: total_price, dtype: float64

# %%
def mean_placer(data): 
     return df[df['sex'] == data['sex']]['total_price'].mean()

# %%
df['mean_price_sex_wise'] = df[['sex','total_price']].apply(mean_placer, axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_price
# 0       16.99  1.01  Female     No  Sun  Dinner     2        18.00  \
# 1       10.34  1.66    Male     No  Sun  Dinner     3        12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3        24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2        26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4        28.20
#
#    mean_price_sex_wise
# 0            20.890345
# 1            23.833694
# 2            23.833694
# 3            23.833694
# 4            20.890345

# %% [markdown]
# # Data Visualization

# %%
# Data Visualization

# Line Plot/Graph               -> Continuous Numerical Data
# Histogram - Freq. of Data     -> Continuous Numerical Data
# Bar Graph                     -> Categorical Data + Continuous Numerical Data
# Box Plot                      -> Continuous Numerical Data, Categorical Data
# Scatter Plot                  -> Two Continuous Numerical Data
# Hexbin                        -> Scatter Plot, points are represented as Hexagon and contains the frequency as color shade
# KDE Plot                      -> Kernel Density Estimator (Smooth Line Plot) Cont. Num. Data
# Pie Chart                     -> Categories with Some Discrete Value
# Violin Plot                   -> Continuous Numerical Data, Categorical Data
# Swarm Plot                    -> Continuous Numerical Data, Categorical Data

# %%
from IPython.display import display, Image
import matplotlib.pyplot as plt

# %%
# Line Plot
display(Image(url='https://onlinestatbook.com/2/graphing_distributions/line_graphs_files/image004b.jpg'))
# Out:
# <img src="https://onlinestatbook.com/2/graphing_distributions/line_graphs_files/image004b.jpg"/>

# %%
# Bar Graph
display(Image(url='https://chartio.com/images/tutorials/charts/grouped-bar-charts/grouped-bar-example-1.png'))
# Out:
# <img src="https://chartio.com/images/tutorials/charts/grouped-bar-charts/grouped-bar-example-1.png"/>

# %%
# Histogram
display(Image(url='https://statistics.laerd.com/statistical-guides/img/uh/laerd-statistics-example-histogram-frequencies-for-age.png'))
# Out:
# <img src="https://statistics.laerd.com/statistical-guides/img/uh/laerd-statistics-example-histogram-frequencies-for-age.png"/>

# %%
# BOX Plot
display(Image(url='https://apexcharts.com/wp-content/uploads/2021/02/basic-boxplot.svg'))
# Out:
# <img src="https://apexcharts.com/wp-content/uploads/2021/02/basic-boxplot.svg"/>

# %%
# Box Plot
display(Image(url='https://miro.medium.com/max/9000/1*2c21SkzJMf3frPXPAR_gZA.png'))
# Out:
# <img src="https://miro.medium.com/max/9000/1*2c21SkzJMf3frPXPAR_gZA.png"/>

# %%
# Scatter Plot
display(Image(url='https://bookdown.org/a_shaker/STM1001_Topic_2/STM1001_Topic_2_files/figure-html/unnamed-chunk-24-1.svg'))
# Out:
# <img src="https://bookdown.org/a_shaker/STM1001_Topic_2/STM1001_Topic_2_files/figure-html/unnamed-chunk-24-1.svg"/>

# %%
# Hexbin
display(Image(url='https://seaborn.pydata.org/_images/hexbin_marginals.png'))
# Out:
# <img src="https://seaborn.pydata.org/_images/hexbin_marginals.png"/>

# %%
# KDE Plot
display(Image(url='https://andrewpwheeler.files.wordpress.com/2021/06/02_kdeweight.png?w=1200'))
# Out:
# <img src="https://andrewpwheeler.files.wordpress.com/2021/06/02_kdeweight.png?w=1200"/>

# %%
# Pie Chart
display(Image(url='https://media.geeksforgeeks.org/wp-content/uploads/20200426195106/plot114.png'))
# Out:
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20200426195106/plot114.png"/>

# %%
# Violin Plot
display(Image(url='https://images.ctfassets.net/fi0zmnwlsnja/sdfgtcRp16wTNOcRceGQm/5bfcb73d2261d49ff20dd7857e0152b1/Screen_Shot_2019-03-01_at_11.36.10_AM.png'))
# Out:
# <img src="https://images.ctfassets.net/fi0zmnwlsnja/sdfgtcRp16wTNOcRceGQm/5bfcb73d2261d49ff20dd7857e0152b1/Screen_Shot_2019-03-01_at_11.36.10_AM.png"/>

# %%
# Swarm Plot
display(Image(url='https://media.geeksforgeeks.org/wp-content/uploads/20200624185342/python-swarmplot.png'))
# Out:
# <img src="https://media.geeksforgeeks.org/wp-content/uploads/20200624185342/python-swarmplot.png"/>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('tips.csv', index_col=0)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Line Plot using Pandas
fig = plt.figure(figsize=(18,6))
df['total_bill'].plot(color='red', linestyle = '-.', marker='o', markerfacecolor='green', markeredgecolor='yellow')
df['tip'].plot()
plt.title('Line Chart by Pandas')
plt.grid('on')
plt.legend(['Total Bill','Tip'])
plt.show()

# %%
# Line Plot using Seaborn
sns.lineplot(data = df, x = df.index, y = 'total_bill')
plt.title('Line Chart by Seaborn')
plt.show()

# %%
df[['total_bill','tip']].plot()
# Out:
# <Axes: >

# %%
# Histograms
fig = plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
df['size'].plot.hist(color='red', bins=5)
plt.grid()
plt.title('Using Pandas')

plt.subplot(1,2,2)
sns.histplot(data = df, x = 'size', bins = 5, color='red')
plt.title('using Seaborn')
plt.show()

# %%
# Bar Plot
fig = plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
df['size'].value_counts().plot.bar()
# df[['day','total_bill']].plot.bar()
plt.title('Pandas')

plt.subplot(1,2,2)
sns.barplot(data = df, x='day', y = 'total_bill', estimator=sum)
plt.title('Seaborn')
plt.show()

# %%
sns.barplot(data = df, x='day', y = 'total_bill', hue = 'sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Boxplot
plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
df['total_bill'].plot.box(); plt.title('Pandas')

plt.subplot(1,2,2)
sns.boxplot(data=df,y='total_bill'); plt.title('SNS')
plt.show()

# %%
# plt.figure(figsize=(18,6))
# plt.subplot(1,2,1)
# df.groupby('day')['total_bill'].plot.box()

# plt.subplot(1,2,2)
sns.boxplot(data=df, x='day', y='total_bill')
plt.show()

# %%
sns.boxplot(data=df, x='day', y='total_bill', hue='sex')
plt.show()

# %%
# Scatter Plot
df.plot.scatter(x='total_bill',y='tip')
plt.show()
sns.scatterplot(data=df, x='total_bill', y='tip')
plt.show()

# %%
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex',size='size')
plt.show()

# %%
# Hexbin
df.plot.hexbin(x='total_bill',y='tip',); plt.show()
sns.jointplot(data=df, x='total_bill',y='tip', kind='hex'); plt.show()

# %%
# KDE Plot
plt.figure(figsize=(18,6))
plt.subplot(141)
df['total_bill'].plot.hist(); 
plt.subplot(142)
df['total_bill'].plot.kde();
plt.subplot(143)
sns.kdeplot(data=df,x='total_bill',hue='day');
plt.subplot(144)
sns.kdeplot(data=df,x='total_bill',y='tip');plt.show()

# %%
# PIE Chart
# df['total_bill'].plot.pie()
df['day'].value_counts().plot.pie(autopct='%d')

# Seaborn does not have pie chart functions
# Out:
# <Axes: ylabel='count'>

# %%
# Violin Plot
sns.violinplot(data=df,x='day',y='tip'); plt.show()

# Swarm Plot
sns.swarmplot(data=df,x='day',y='tip'); plt.show()

# %%
# Heatmap
sns.heatmap(df[['total_bill','tip','size']]); plt.show()

# %%
df[['total_bill','tip','size']].corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df[['total_bill','tip','size']].corr(), fmt='1.4f', annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df[['total_bill','tip','size']].corr(), fmt='1.4f', annot=True, cmap='magma')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
sns.set_style('dark') # white, dark, whitegrid, darkgrid, ticks

# %%
# Violin Plot
sns.violinplot(data=df,x='day',y='tip'); plt.show()

# Swarm Plot
sns.swarmplot(data=df,x='day',y='tip'); plt.show()

# %%
# Data Visualization
#######################
sns.set_style('whitegrid')      # white, dark, whitegrid, darkgrid, ticks

# Line Plot/Graph               -> Continuous Numerical Data
df[['total_bill','tip']].plot(color='red', linestyle = '-.', marker='o', markerfacecolor='green', markeredgecolor='yellow')

# Histogram - Freq. of Data     -> Continuous Numerical Data
sns.histplot(data = df, x = 'size', bins = 5, color='red')

# Bar Graph                     -> Categorical Data + Continuous Numerical Data
sns.barplot(data = df, x='day', y = 'total_bill', estimator=sum)

# Box Plot                      -> Continuous Numerical Data, Categorical Data
sns.boxplot(data=df, x='day', y='total_bill', hue='sex')

# Scatter Plot                  -> Two Continuous Numerical Data
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex',size='size')

# Hexbin                        -> Scatter Plot, points are represented as Hexagon and contains the frequency as color shade
sns.jointplot(data=df, x='total_bill',y='tip', kind='hex'); plt.show()

# KDE Plot                      -> Kernel Density Estimator (Smooth Line Plot) Cont. Num. Data
sns.kdeplot(data=df,x='total_bill',hue='day')

# Pie Chart                     -> Categories with Some Discrete Value
df['day'].value_counts().plot.pie(autopct='%d')

# Violin Plot                   -> Continuous Numerical Data, Categorical Data
sns.violinplot(data=df,x='day',y='tip')

# Swarm Plot                    -> Continuous Numerical Data, Categorical Data
sns.swarmplot(data=df,x='day',y='tip')

# Heatmap
sns.heatmap(df[['total_bill','tip','size']].corr(), fmt='1.4f', annot=True, cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# ## Machine Learning / Deep Learning

# %%
## Machine Learning / Deep Learning

# Supervised Learnig
# Unsupervised Learning
# Reinforcement Learning
# Semi Supervised

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Linear Regression
df = pd.read_csv('housing.csv')

# %%
# Exploratory Data Analysis (EDA)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms
# count       5000.000000          5000.000000                5000.000000  \
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
target = 'Price'       # categorical or numerical ?
feats = []

# %%
df['Price'].nunique()
# Out:
# 5000

# %%
sns.set_style('whitegrid')

# %%
sns.histplot(data=df, x=target)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
cols = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']
for col in cols:
     print(col,':',df[col].nunique())
# Out:
# Avg. Area Income : 5000
# Avg. Area House Age : 5000
# Avg. Area Number of Rooms : 5000
# Avg. Area Number of Bedrooms : 255
# Area Population : 5000

# %%
5000/255
# Out:
# 19.607843137254903

# %%
(100*20)/5000
# Out:
# 0.4

# %%
5000/4
# Out:
# 1250.0

# %%
df['Address'].sample(10)
# Out:
# 4815             2206 Michael Place\nKevinhaven, TX 51899
# 2382    940 Kelsey Light Suite 026\nBeckstad, GU 27370...
# 772     2627 Ford Spurs Suite 995\nChristopherton, KY ...
# 2011          91286 Small Shoal\nNew Jacqueline, CO 84213
# 4143    611 Mark Union Apt. 823\nNorth Richardtown, GU...
# 4781    22503 Rachel Street Suite 650\nSouth Jordanbur...
# 3695    1994 Lauren Plaza Apt. 187\nNew Carolberg, PR ...
# 4638    528 Ortiz Island Suite 512\nNorth Taylor, MO 6...
# 640     9067 Flynn Mills Apt. 904\nNorth Stevenland, W...
# 1776    4287 Jeremy Island Suite 935\nGeraldmouth, TN ...
# Name: Address, dtype: object

# %%
drop_cols = ['Address']

# %%
num_cols = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']

# %%
for col in num_cols:
    sns.scatterplot(data=df, x=target, y=col)
    plt.show()

# %%
for col in num_cols:
    sns.jointplot(data=df, x=target, y=col, kind='reg')
    plt.show()

# %%
sns.pairplot(df, kind='reg')

# %%
sns.heatmap(df.drop(drop_cols,axis=1).corr(), annot=True, fmt='.2f')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
feats += ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Area Population']

# %%
target
# Out:
# 'Price'

# %%
features = df[feats]
label = df[target]

# %%
features.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms
# 0      79545.458574             5.682861                   7.009188  \
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Area Population
# 0     23086.800503
# 1     40173.072174
# 2     36882.159400
# 3     34310.242831
# 4     26354.109472

# %%
features.shape
# Out:
# (5000, 4)

# %%
# !python -m pip install scikit-learn

# %%
# import sklearn

# %%
# Data Splitting -> Train Data and Test Data
from sklearn.model_selection import train_test_split

# Train the model
from sklearn.linear_model import LinearRegression

# %%
help(train_test_split)
# Out:
# Help on function train_test_split in module sklearn.model_selection._split:
#
# train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)
#     Split arrays or matrices into random train and test subsets.
#
#     Quick utility that wraps input validation,
#     ``next(ShuffleSplit().split(X, y))``, and application to input data
#     into a single call for splitting (and optionally subsampling) data into a
#     one-liner.
#
#     Read more in the :ref:`User Guide <cross_validation>`.
#
#     Parameters
#     ----------
#     *arrays : sequence of indexables with same length / shape[0]
#         Allowed inputs are lists, numpy arrays, scipy-sparse
#         matrices or pandas dataframes.
#
#     test_size : float or int, default=None
#         If float, should be between 0.0 and 1.0 and represent the proportion
#         of the dataset to include in the test split. If int, represents the
# ...

# %%
k = train_test_split(features, label, test_size = 0.25, random_state = 40)
train_feat, test_feat, train_label, test_label = k

# %%
train_feat.shape
# Out:
# (3750, 4)

# %%
train_label.shape
# Out:
# (3750,)

# %%
model = LinearRegression().fit(train_feat, train_label)

# %%
model
# Out:
# LinearRegression()

# %%
# Evaluate The Trained Model
###############################
# Performance Indices
    # Regression
        # Errors - Mean Absoulte Error (MAE), MSE, RMSE, r2Error
    # Classification
        # Confusion Matrix
        # Precision
        # Recall
        # r2Score

# %%
help(model.score)
# Out:
# Help on method score in module sklearn.base:
#
# score(X, y, sample_weight=None) method of sklearn.linear_model._base.LinearRegression instance
#     Return the coefficient of determination of the prediction.
#
#     The coefficient of determination :math:`R^2` is defined as
#     :math:`(1 - \frac{u}{v})`, where :math:`u` is the residual
#     sum of squares ``((y_true - y_pred)** 2).sum()`` and :math:`v`
#     is the total sum of squares ``((y_true - y_true.mean()) ** 2).sum()``.
#     The best possible score is 1.0 and it can be negative (because the
#     model can be arbitrarily worse). A constant model that always predicts
#     the expected value of `y`, disregarding the input features, would get
#     a :math:`R^2` score of 0.0.
#
#     Parameters
#     ----------
#     X : array-like of shape (n_samples, n_features)
#         Test samples. For some estimators this may be a precomputed
#         kernel matrix or a list of generic objects instead with shape
# ...

# %%
model.score(test_feat, test_label) * 100
# Out:
# 91.44901090753275

# %%
# Deploy the model

# %%
model.feature_names_in_
# Out:
# array(['Avg. Area Income', 'Avg. Area House Age',
#        'Avg. Area Number of Rooms', 'Area Population'], dtype=object)

# %%
round(3456.37428678365743,2)
# Out:
# 3456.37

# %%
inc = eval(input('Enter Income:'))
age = eval(input('Enter House Age:'))
room = eval(input('Enter num of rooms:'))
pop = eval(input('Enter population:'))
query = [[inc,age,room,pop]]
query = pd.DataFrame(query, columns=model.feature_names_in_)
pred = model.predict(query)
print(round(pred[0],2))
# Out:
# 421673.04

# %%
model.coef_
# Out:
# array([2.15020699e+01, 1.65916430e+05, 1.21783809e+05, 1.50686194e+01])

# %%
coeff = pd.DataFrame(model.coef_, index=model.feature_names_in_, columns=['Coeff'])
coeff
# Out:
#                                    Coeff
# Avg. Area Income               21.502070
# Avg. Area House Age        165916.429626
# Avg. Area Number of Rooms  121783.809160
# Area Population                15.068619

# %%
test_label_pred = model.predict(test_feat)

# %%
test_label_pred[0]
# Out:
# 1437663.841146266

# %%
test_label.values[0]
# Out:
# 1435769.7688373898

# %%
sns.scatterplot(x = test_label_pred, y=test_label)
# Out:
# <Axes: ylabel='Price'>

# %%
# Summary
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv('housing.csv')
target = 'Price'
feats = ['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms','Area Population']
features = df[feats]
label = df[target]
train_feat, test_feat, train_label, test_label = train_test_split(features, label, test_size = 0.25, random_state = 40)
model = LinearRegression().fit(train_feat, train_label)
print('Test Score: ',round(model.score(test_feat, test_label) * 100, 2), '%')
print('Train Score: ',round(model.score(train_feat, train_label) * 100, 2), '%')

# Save the Model
pd.to_pickle(model, 'housePricePredictor.pkl')
# Out:
# Test Score:  91.45 %
# Train Score:  91.91 %

# %%
# Load Model
house = pd.read_pickle('housePricePredictor.pkl')
house
# Use the Prediction Model
inc = eval(input('Enter Income:'))
age = eval(input('Enter House Age:'))
room = eval(input('Enter num of rooms:'))
pop = eval(input('Enter population:'))
query = [[inc,age,room,pop]]
query = pd.DataFrame(query, columns=model.feature_names_in_)
pred = house.predict(query)
print(round(pred[0],2))
# Out:
# 421673.04

# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(0)
x = 2 - 3 * np.random.normal(0,1,20)
y = x - 2 * (x**2) + 0.5 * (x**3) + np.random.normal(-3,3,20)

# %%
plt.scatter(x,y)

# %%
x = x.reshape(-1,1)
y = y.reshape(-1,1)

model = LinearRegression()
model.fit(x,y)
y_pred = model.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred, color = 'r')
plt.show()

# %%
# poly example
arr = np.array([1,2,3,4]).reshape(-1,1)
arr
# Out:
# array([[1],
#        [2],
#        [3],
#        [4]])

# %%
#poly_features = PolynomialFeatures(degree= 3)
#new_arr = poly_features.fit_transform(arr)
#new_arr

# %%
#poly_features.get_feature_names_out()

# %% [markdown]
# lets apply polynomial regression

# %%
poly_features = PolynomialFeatures(degree = 3)
x_poly = poly_features.fit_transform(x)

pr_model = LinearRegression()
pr_model.fit(x_poly,y)
pr_y_pred = pr_model.predict(x_poly)

# %%
sort_index = x.flatten().argsort()
x_sorted = x.flatten()[sort_index]
pr_y_pred_sorted = pr_y_pred[sort_index]

# %%
plt.scatter(x,y)
plt.plot(x_sorted,pr_y_pred_sorted, color = 'r')
plt.show()

# %% [markdown]
# New Data

# %%
n = 1000
x1 = np.random.randint(1,10,n)
x2 = np.linspace(0, .5, n)

noise = np.random.normal(0,0.5,n)
y = np.sin(x1) + np.cos(x2) + noise

df = pd.DataFrame({'x1':x1, 'x2':x2, 'y': y })
df
# Out:
#      x1        x2         y
# 0     4  0.000000 -0.418179
# 1     6  0.000501  0.884322
# 2     5  0.001001  0.078277
# 3     5  0.001502  0.061614
# 4     7  0.002002  2.286803
# ..   ..       ...       ...
# 995   4  0.497998 -0.417511
# 996   9  0.498498  1.457133
# 997   3  0.498999  1.489349
# 998   5  0.499499  0.050217
# 999   4  0.500000  0.459205
#
# [1000 rows x 3 columns]

# %%
# lr model
model = LinearRegression()
model.fit(df[['x1','x2']], df['y'])
# Out:
# LinearRegression()

# %%
X = df[['x1','x2']]
df['y_pred'] = model.predict(X)

# %%
# !python -m pip install plotly

# %%
import plotly.graph_objects as go

# %%
fig = go.Figure(data=[go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y'], mode = "markers", name = "Actual", marker= dict(size =3))])
fig.add_trace(go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y_pred'], mode = "markers", name = "Actual", marker= dict(size =3)))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[224], line 4
#       1 fig = go.Figure(data=[go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y'], mode = "markers", name = "Actual", marker= dict(size =3))])
#       2 fig.add_trace(go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y_pred'], mode = "markers", name = "Actual", marker= dict(size =3)))
# ----> 4 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\basedatatypes.py:3409, in BaseFigure.show(self, *args, **kwargs)
#    3376 """
#    3377 Show a figure using either the default renderer(s) or the renderer(s)
#    3378 specified by the renderer argument
#    (...)
#    3405 None
#    3406 """
#    3407 import plotly.io as pio
# -> 3409 return pio.show(self, *args, **kwargs)
#
# ...

# %%
poly = PolynomialFeatures(degree=3)
x_poly = poly.fit_transform(df[['x1','x2']])

p_model = LinearRegression()
p_model.fit(x_poly, df['y'])
# Out:
# LinearRegression()

# %%
df['p_y_pred'] = p_model.predict(x_poly)

fig = go.Figure(data=[go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y'], mode = "markers", name = "Actual", marker= dict(size =3))])
fig.add_trace(go.Scatter3d(x= df['x1'], y = df['x2'], z = df['p_y_pred'], mode = "markers", name = "Actual", marker= dict(size =3)))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[226], line 6
#       3 fig = go.Figure(data=[go.Scatter3d(x= df['x1'], y = df['x2'], z = df['y'], mode = "markers", name = "Actual", marker= dict(size =3))])
#       4 fig.add_trace(go.Scatter3d(x= df['x1'], y = df['x2'], z = df['p_y_pred'], mode = "markers", name = "Actual", marker= dict(size =3)))
# ----> 6 fig.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\basedatatypes.py:3409, in BaseFigure.show(self, *args, **kwargs)
#    3376 """
#    3377 Show a figure using either the default renderer(s) or the renderer(s)
#    3378 specified by the renderer argument
#    (...)
#    3405 None
#    3406 """
#    3407 import plotly.io as pio
# -> 3409 return pio.show(self, *args, **kwargs)
#
# ...

# %% [markdown]
# For Linear Regression

# %%
#MAE
from sklearn.metrics import mean_absolute_error
print('MAE of LR :', mean_absolute_error(df['y'],df['y_pred']))
# Out:
# MAE of LR : 0.7255933452620693

# %%
#MSE
from sklearn.metrics import mean_squared_error
print('MSE of LR :', mean_squared_error(df["y"],df['y_pred']))
# Out:
# MSE of LR : 0.7693143600431358

# %%
#RMSE
print('RMSE of LR:', np.sqrt(mean_squared_error(df["y"],df['y_pred'])))
# Out:
# RMSE of LR: 0.8771056721074924

# %%
#R2
from sklearn.metrics import r2_score
print('R2_score of LR :', r2_score(df["y"],df['y_pred']))
# Out:
# R2_score of LR : 0.00021846594540997355

# %% [markdown]
# For Polynomial Regression

# %%
print('MAE of PR :', mean_absolute_error(df['y'],df['p_y_pred']))
print('MSE of PR :', mean_squared_error(df["y"],df['p_y_pred']))
print('RMSE of PR:', np.sqrt(mean_squared_error(df["y"],df['p_y_pred'])))
print('R2_score of PR :', r2_score(df["y"],df['p_y_pred']))
# Out:
# MAE of PR : 0.5715532364668434
# MSE of PR : 0.47661407977218256
# RMSE of PR: 0.690372421068645
# R2_score of PR : 0.3806043659448509
